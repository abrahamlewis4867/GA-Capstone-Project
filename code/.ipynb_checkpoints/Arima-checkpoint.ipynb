# %%
import pandas as pd # packages for reading in data
import numpy as np
import matplotlib.pyplot as plt  # packages for displaying data
from matplotlib.patches import Rectangle
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf, pacf #packages for statistics
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import r2_score,  mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.stattools import adfuller
from pmdarima import auto_arima
f

from pmdarima import auto_arima

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

sns.set_style("darkgrid") # setting style

# %%
df = pd.read_csv("../data/chennai_complete.csv",index_col='date',parse_dates=True, # setting the index to datetime
                 usecols=['date','chembarambakkam_water','chembarambakkam_rain']) # selecting columns

# %%
df = df.resample("M").mean()

# %%
adfuller(df["chembarambakkam_water"])
# Out:
# (-3.9833081000530304,
#  0.0015004816743128208,
#  2,
#  189,
#  {'1%': -3.4654311561944873,
#   '5%': -2.8769570530458792,
#   '10%': -2.574988319755886},
#  2534.8271277324893)

# %% [markdown]
# What the second equation is saying is that the future change in Y is a linear function of the past changes in Y. Why bother with differencing? The reason is that differences are generally much more stationary than the raw undifferenced values. When we do time series modeling, we like our Y variables to be mean variance stationary. This means that the main statistical properties of a model do not vary depending on when the sample was taken. Models built on stationary data are generally more robust.

# %%
plot_acf(df['chembarambakkam_water'], lags =25)
plt.xlabel("Lag Number")
plt.ylabel("Autocorrelation with lag = 0")
plt.title("Autocorrelation for Chembarambakka");

# %%
plot_pacf(df['chembarambakkam_water'], lags = 25)
plt.xlabel("Lag Number")
plt.ylabel("Partial Autocorrelation with lag = 0")
plt.title("Partial Autocorrelation for Chembarambakka");

# %% [markdown]
# ## Modeling
# ---

# %% [markdown]
# ### Baseline

# %% [markdown]
# Before we model, we are going to establish a baseline model by which to compare all other results.

# %%
df_dumb = df["chembarambakkam_water"]

# %%
values = df_dumb
dataframe = pd.concat([values.shift(1), values], axis=1) #lagging the data a mont
dataframe.columns = ['t', 't+1']
print(dataframe.head(5))
# Out:
#               t  t+1
# date
# 2004-01-31  NaN  0.0
# 2004-02-29  0.0  0.0
# 2004-03-31  0.0  0.0
# 2004-04-30  0.0  0.0
# 2004-05-31  0.0  0.0

# %%
X = dataframe['t+1']
y= dataframe['t']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .34, shuffle = False)

# %%
test_score = mean_squared_error(y_test, X_test)
print(f'Test MSE: {test_score}')
# Out:
# Test MSE: 131725.53848875794

# %% [markdown]
# **Interpretation**: This Baseline Model is the simplest possible model, lagging the data for one month and predicting the next month. This model has a MSE of 131725.538 which we will use as a benchmark for future models.

# %% [markdown]
# ### ARIMA
#
# ---

# %% [markdown]
# #### Model Pre-processing

# %% [markdown]
# We are now going to be modeling are time-series data with an ARIMA Model.

# %% [markdown]
# An ARIMA model has three components.
# 1.  AR: Autoregressive. This means we regress the target variable on its own past values. In our case lagging a month or months of data.
#
#
#
# 2.  I: Integrated. This shows we are differencing the data.
#
#
#
#
# 3. MA: Moving Average. This is a model that forecasts Y using our model’s past errors to correct our model's forecast.

# %%
y = df["chembarambakkam_water"]

y_train_ar, y_test_ar = train_test_split(y, test_size = .34, shuffle = False)

# %% [markdown]
# Now that we have split the data, we can run the Auto ARIMA.

# %%
fitted_arima = auto_arima(
    y_train, # data
    start_p = 0,
    start_q = 0,
    max_p = 2,
    max_q = 2,
    d = 0, 
    stationary = True, # in this case our data is  stationary
    seasonal=True, 
    solver='lbfgs', 
    trace=True,
    error_action='ignore',  
    suppress_warnings=True  
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=2068.506, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1836.633, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1938.102, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2228.823, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1804.365, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1805.127, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1807.127, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1812.970, Time=0.02 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 0.341 seconds

# %% [markdown]
# We ran an auto ARIMA to calculate the best parameter for  the model.

# %% [markdown]
# ---

# %%
Af

# %%
X = df.chembarambakkam_water.values # getting the values

size = int(len(X) * 0.66) 

train, test = X[0:size], X[size:len(X)] # Splitting data
    
history =  list(train) # making the train into a list 

predictions = list() #setting up a list for the predictions

for t in range(len(test)): #using the len of the testset to go through data
    
    model = ARIMA(history, order=(1,0,1))
    
    model_fit = model.fit(disp=0) #fitting model and stopping display data
    
    output = model_fit.forecast() #forcasting 
    
    yhat = output[0] #feeding the predictions into the variable
    
    predictions.append(yhat) #appending the predictions to the list we create
    
    obs = test[t] 
    
    history.append(obs)
    
    print('predicted=%f, expected=%f' % (yhat, obs))
    
error = mean_squared_error(test, predictions)

print(f'Test MSE: {error}') #printing the rmse
# Out:
# predicted=1167.625045, expected=990.645161
# predicted=957.780505, expected=741.096774
# predicted=717.263427, expected=615.266667
# predicted=662.514095, expected=940.548387
# predicted=1139.149992, expected=1221.833333
# predicted=1288.307835, expected=1081.032258
# predicted=1018.788663, expected=931.709677
# predicted=947.920225, expected=690.857143
# predicted=649.663759, expected=842.290323
# predicted=1008.175683, expected=788.133333
# predicted=754.382823, expected=694.064516
# predicted=749.509669, expected=530.200000
# predicted=524.367177, expected=409.354839
# predicted=467.237805, expected=246.741935
# predicted=267.790410, expected=174.400000
# predicted=263.709091, expected=210.032258
# predicted=312.830105, expected=1897.000000
# predicted=2608.469276, expected=3138.225806
# predicted=3154.795855, expected=3028.580645
# predicted=2737.807534, expected=3041.793103
# predicted=2983.484520, expected=2628.032258
# predicted=2272.370098, expected=2223.266667
# predicted=2084.700650, expected=2396.064516
# predicted=2428.145850, expected=2138.000000
# predicted=1883.528450, expected=1784.225806
# predicted=1681.311280, expected=1350.387097
# predicted=1184.382287, expected=1057.966667
# predicted=1043.214533, expected=776.580645
# predicted=725.106737, expected=396.233333
# predicted=361.452724, expected=471.806452
# predicted=662.595574, expected=482.064516
# predicted=513.274401, expected=249.607143
# predicted=264.094349, expected=375.451613
# predicted=574.201548, expected=381.166667
# predicted=413.578956, expected=189.193548
# predicted=226.717060, expected=56.466667
# predicted=136.786622, expected=72.322581
# predicted=204.754683, expected=107.935484
# predicted=215.874407, expected=214.233333
# predicted=358.146861, expected=303.612903
# predicted=406.512143, expected=1293.900000
# predicted=1775.027315, expected=1883.225806
# predicted=1866.455956, expected=1773.387097
# predicted=1664.751655, expected=1606.250000
# predicted=1539.137269, expected=1372.709677
# predicted=1279.149418, expected=1116.700000
# predicted=1060.263934, expected=1275.290323
# predicted=1402.482016, expected=1063.133333
# predicted=919.307264, expected=773.548387
# predicted=773.708771, expected=525.032258
# predicted=501.655872, expected=391.966667
# predicted=460.209471, expected=291.774194
# predicted=339.341690, expected=196.533333
# predicted=268.170422, expected=141.000000
# predicted=225.926442, expected=73.032258
# predicted=149.995876, expected=36.500000
# predicted=136.729536, expected=15.161290
# predicted=111.063340, expected=5.633333
# predicted=108.866468, expected=1.193548
# predicted=101.333062, expected=0.833333
# predicted=102.473908, expected=0.000000
# predicted=98.435236, expected=0.000000
# predicted=98.258627, expected=3.733333
# predicted=101.522307, expected=20.903226
# predicted=122.299648, expected=409.233333
# predicted=663.409622, expected=1230.782609
# Test MSE: 90810.76703580309

# %% [markdown]
# **Interpretation**: Our model got an MSE score of 90,810; this is considerably better than the baseline of 131,725.
#
# The next steps would be:
#
# * to further tuning the p, d, q
# * to gather more data
# * to forecast over different periods.

# %% [markdown]
# ---

# %% [markdown]
# ## Model Selection
# ---

# %% [markdown]
# We are selecting the ARIMA model for evaluation.

# %% [markdown]
# ## Model Evaluation
# ---

# %% [markdown]
# #### Evaluating the RMSE

# %%
print(f'The RMSE is: {round(rmse,2) }' )
# Out:
# The RMSE is: 1078.82

# %% [markdown]
# **Interpretation:** According to the value of the RMSE, the predictions for average monthly water lever made by the model are likely off by about 1078.82 cubic million feet. In the future I would like to improve this number to increase the predictability of the model.

# %% [markdown]
# #### Looking at the Residuals

# %%
residuals = pd.DataFrame(model_fit.resid)
residuals.plot();

# %%
residuals.plot(kind='kde');

# %%
print(residuals.describe())
# Out:
#                  0
# count   191.000000
# mean      1.766270
# std     321.704375
# min   -1217.091999
# 25%    -159.814886
# 50%     -85.614076
# 75%     107.991400
# max    1983.441184

# %% [markdown]
# ### Visualizing Predictions

# %%
plt.figure(figsize=((10, 6)))
plt.title("Average water level by month using out-of-sample predictions")

plt.ylabel("water level in millions of cubic feet")
plt.plot(predictions, color='red', ls= 'dashed', label= "predictions");
plt.plot(test);

# %% [markdown]
# **Interpretation**:

# %% [markdown]
# A rolling forecast is required given the dependence on observations in prior time steps for differencing and the AR model. A crude way to perform this rolling forecast is to re-create the ARIMA model after each new observation is received.

# %%
A line plot is created showing the expected values (blue) compared to the rolling forecast predictions (red). We can see the values show some trend and are in the correct scale.

# %%
The difference the actual predictive value in our time step and y hat time step.

# %% [markdown]
# Similarly to the AR part, we are doing something with historical values here, hence all the lags. But what is this E? E is commonly called error in most explanations of MA models, and it represents the random residual deviations between the model and the target variable (if you’re asking how it’s possible that we can have errors before we’ve even fit the model, hold that thought for just a second).
# The full equation of a basic regression model is:

# %% [markdown]
#  E represents the difference between the exact answer and the approximately correct answer delivered by our model.

# %% [markdown]
#  MLE (Maximum Likelihood Estimation)

# %% [markdown]
# p is the parameter associated with the auto-regressive aspect of the model, which incorporates past values. For example, forecasting that if it rained a lot over the past few days, you state its likely that it will rain tomorrow as well.

# %% [markdown]
# This model has an AR number of auto regressin lags
# of 2

# %%
y
